# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv("Historical Product Demand.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029518 entries, 0 to 1029517
# Data columns (total 5 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Product_Code      1029518 non-null  object
#  1   Warehouse         1029518 non-null  object
#  2   Product_Category  1029517 non-null  object
#  3   Date              1018278 non-null  object
#  4   Order_Demand      1029517 non-null  object
# dtypes: object(5)
# memory usage: 39.3+ MB

# %%
df.head()
# Out:
#    Product_Code Warehouse Product_Category       Date Order_Demand
# 0  Product_0993    Whse_J     Category_028  2012/7/27         100
# 1  Product_0979    Whse_J     Category_028  2012/1/19         500
# 2  Product_0979    Whse_J     Category_028   2012/2/3         500
# 3  Product_0979    Whse_J     Category_028   2012/2/9         500
# 4  Product_0979    Whse_J     Category_028   2012/3/2         500

# %%
df.shape
# Out:
# (1029518, 5)

# %%
df.sample(10)
# Out:
#         Product_Code Warehouse Product_Category        Date Order_Demand
# 84819   Product_0784    Whse_J     Category_001   2012/12/5           5
# 195317  Product_1869    Whse_J     Category_001   2012/4/12           1
# 3291    Product_2141    Whse_S     Category_009   2012/7/31         100
# 494599  Product_2029    Whse_J     Category_005   2014/12/5         100
# 612940  Product_1315    Whse_J     Category_019    2014/7/2         100
# 255749  Product_1295    Whse_J     Category_019  2013/10/22        5000
# 644282  Product_2045    Whse_J     Category_019   2015/2/23       10000
# 971599  Product_1154    Whse_J     Category_006   2016/3/15        4000
# 202004  Product_1616    Whse_S     Category_024    2012/4/5          16
# 273003  Product_1643    Whse_C     Category_019  2012/12/14         500

# %%
df.isna().sum()
# Out:
# Product_Code            0
# Warehouse               0
# Product_Category        1
# Date                11240
# Order_Demand            1
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (1018278, 5)

# %%
df['Order_Demand'].describe()
# Out:
# count     1018278
# unique       3743
# top         1000
# freq       110656
# Name: Order_Demand, dtype: object

# %%
df['Order_Demand'].dtype
# Out:
# dtype('O')

# %%
df['Order_Demand'] = df['Order_Demand'].replace('[\$,)]', '', regex = True).replace('[()]', '-', regex = True).astype(float)

# %%
df['Order_Demand'].head()
# Out:
# 0    100.0
# 1    500.0
# 2    500.0
# 3    500.0
# 4    500.0
# Name: Order_Demand, dtype: float64

# %%
df['Order_Demand'].describe()
# Out:
# count    1.018278e+06
# mean     4.999886e+03
# std      2.934033e+04
# min     -9.990000e+05
# 25%      2.000000e+01
# 50%      3.000000e+02
# 75%      2.000000e+03
# max      4.000000e+06
# Name: Order_Demand, dtype: float64

# %%
df['Date'] = pd.to_datetime(df['Date'], format = '%Y/%m/%d')
df['DayOfWeek'] = df['Date'].dt.day_of_week
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year
df['Period'] = df['Date'].dt.to_period('M')
df.sort_values('Date', inplace = True)

# %%
df.sample(10)
# Out:
#         Product_Code Warehouse Product_Category       Date  Order_Demand  \
# 207115  Product_0200    Whse_S     Category_007 2013-11-13         153.0
# 470751  Product_1521    Whse_J     Category_019 2014-04-04        4000.0
# 162574  Product_0930    Whse_J     Category_006 2012-08-17        1000.0
# 176406  Product_1749    Whse_J     Category_001 2012-05-07           1.0
# 211124  Product_0221    Whse_S     Category_007 2013-05-16         500.0
# 895847  Product_2085    Whse_A     Category_009 2016-07-14           8.0
# 962985  Product_0984    Whse_J     Category_028 2016-03-22         500.0
# 280619  Product_1266    Whse_J     Category_019 2013-05-10        1000.0
# 701170  Product_0206    Whse_C     Category_007 2015-01-02         833.0
# 308026  Product_1622    Whse_J     Category_019 2013-11-15         100.0
#
#         DayOfWeek  Month  Year   Period
# 207115          2     11  2013  2013-11
# 470751          4      4  2014  2014-04
# 162574          4      8  2012  2012-08
# 176406          0      5  2012  2012-05
# 211124          3      5  2013  2013-05
# 895847          3      7  2016  2016-07
# 962985          1      3  2016  2016-03
# 280619          4      5  2013  2013-05
# 701170          4      1  2015  2015-01
# 308026          4     11  2013  2013-11

# %%
df.loc[df.sample(int(df.shape[0] * 0.05)).index, ['Order_Demand']] = np.nan

# %%
df.loc[(df['Period'] == '2002-05')]

# %%
from numpy.core.fromnumeric import size
df['user'] = np.random.choise(['Usuario 1', 'Usuario 2'], )
